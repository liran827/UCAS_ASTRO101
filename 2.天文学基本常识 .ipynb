# %% [markdown]
# # 第二部分 天文学基本常识
#
# ## 目录
#
# 一些基本概念
#
# 天球坐标系
#
# 从星光中读取信息
#
# 天文学家的望远镜

# %% [markdown]
# ## 一些基本概念
#
# ### 星等，光度，流量
#
# 流量：单位面上接收到的光能, F, 单位 $ W m^{-2}$
#
# 光度：恒星的总功率
#
# $L=\frac{F}{4\pi D_l^2}$
#
# 星等：恒星的亮度。古希腊人把最亮的恒星标记为1等，最暗的标记为6等，两者之间的观测流量相差100倍。
#
# m1-m2= 2.5* log10(F2/F1)
#
# 视星等：表示地球上观测者观测到到的恒星亮度
#
# 绝对星等：恒星在10pc的距离上的亮度，太阳的绝对星等是 4.74
#
#
# $M=m+5\log(\frac{d}{10 pc})$
#
# $ M=M_{\odot}- 2.5\log{L/L_{\odot}} $
#
# 思考：太阳在所有波段的绝对星等都是4.74吗？
#
#
# Vega magnitude system: Vega在任何波段都是0等。
#
# AB magnitude system:
#
# 在任何波段，0等星的亮度是是3631 janskys （Jy), [1] where
# $1 Jy = 10^{−26} W Hz^{−1} m^{−2} = 10^{−23} erg s^{−1} Hz^{−1} cm^{−2}$
#
#
# ### 光年，秒差距，红移
#
# ### 角度，角秒
# 3. 天球坐标

# %% [markdown]
# 当我们研究天空的时候，需要解决的第一个问题是如何记录夜空。我们星座是一种努力的方式，利用图形来记忆。但当需要记录的天体增多，这样的方法不再实用。
#
# 考虑一个边长为1米的球体 （球的半径不重要），我们在球体中心。再想象地球是透明的，那么所有天上的天体都在地球上有投影。我们合理的建立球面坐标系，可以对每一个天体进行记录。
#
#
# 如何建立一个球面坐标系。想象一下地球仪，我们需要定义基本轴（基本圈）和起算点。
#
# ### 地平坐标系
#
#
# 地平坐标系是最符合自然的记录方式。
#
# 概念：
#
# 天顶，天极，天底，
#
# 基本圈：地平圈
#
# 北点，连接天顶，天极
#
# 东西南北四基本点
#
# 天赤道：垂直天极的大圆
#
# 方位角 （Azimuth, A)：从北点起算，顺时针
# 高度角  (Altithude, h):天体所在的平行水平圈的小圆和水平圈之间的圆心角角度差
#
# 问题一：
# 北极星的高度角和当地纬度的关系？
#
#
# 地平坐标系的缺点：
# 每晚天体高度角，方位都不同，除了北极星
# 但对于爱好者很自然
#
#
#
#
# ### 第一赤道坐标系（时角坐标系）
#
# 思考以恒星背景作为参考系。太阳相对恒星背景静止（每一太阳年的同一天）
#
# 论述太阳的周年视运动，地球逆时针绕太阳运动，太阳也逆时针在天球上运动
#
# 黄道：太阳在天球上运动的大圆。黄道和赤道交角23.5度
#
# 春分点：黄道和天赤道的升焦点
#
# 思考：为什么春分点正好是春天？
#
# 以天赤道作为基本圈，经度以太阳的位置作为起算点。
#
# 时角 t: 从南点起算，向西为正，向东为负。360度分为24小时。天体东升西落。上中天时时角为0.若为-8小时，则8小时候上中天。
# 赤纬 $\delta$: 和天赤道平行的小圆，和天赤道的纬度差。天赤道是0度，北天极是90度
#
# 子午圈：连接天极，南北点
#
# 思考：如果伦敦太阳时角为0.那么北京的观测者，太阳时角为何？
#
# ### 第二赤道坐标系
#
# 赤经 （right ascension, RA, $\alpha$)：春分点起算，逆时针。
# 赤纬  (DEC, declination, $\delta$): 从天赤道起算，天赤道为0， 北天极为90
#
# 星表中天体位置绝大多数情况下以第二赤道坐标系记录
#
# 根据当地纬度，和赤纬，可以判断什么天体永远不会在本地看见。
#
# 思考：午夜过中天的天体，赤经是多少？ （12h)
#
# 思考：哪些天体永远不会升起。哪些天体永远不会落下？
#
# 思考：天体赤经为17h, 赤纬60度。在6月22日的北京是否能看见？
# 夏至，太阳的赤经为6h. 可以看见。
#
# ### 星空的长时间变化
#
# 北极星的位置演变
#
# 短期变化
#
# 进动和章动

# %% [markdown]
# ## 历法
#
# ### 真太阳时
#
# 真太阳视圆面中心连续两次上中天的时间间隔为1真太阳日。1真太阳日划分为24真太阳小时，1真太阳时=60真太阳分，1真太阳分=60真太阳秒。真太阳时的计量起点是真太阳上中天，其时刻就是时角。为了照顾生活习惯，1925年起，真太阳时定义为，即将起点定在下中天时刻。
#
# 真太阳的视运动是地球自转和公转运动的共同反映。地球的公转轨道是椭圆，公转速度不均匀，而且自转轴不垂直于公转轨道面。以上原因使得真太阳日的长度每天都不同。真太阳时与日常生活的节律一致。真太阳日的长度比地球的自转周期长。
#
# <font color=red> 真太阳时不是均匀的时间计量系统。</font>
#
# ### 恒星时
# 春分点连续两次上中天的时间间隔为1恒星日.恒星日也划分为恒星小时、恒星分和恒星秒.
# 恒星时的起点定义为春分点上中天。
#
# 恒星时不是均匀的时间系统.太阳相对于春分点运动.恒星时与日常生活的节律有偏差，故不能用于日常生活中的计时量。
# 在天文观测中，观测时刻必须用恒星时计量。
#
# ### 平太阳时
# 为了克服真太阳时的缺陷，引入了一个假想的参考点——平太阳，据此建立了平太阳时，简称平时，并将格林尼治子午圈的平时称为世界时。
# 第一辅助点——黄道平太阳。在黄道上做匀速运动，其视运动的速度等于太阳视运动速度的平均值，并且与真太阳同时经过近地点和远地点。
# 第二辅助点——赤道平太阳。在赤道上做匀速运动，不仅与第一辅助点速度相同，而且两者同时经过春分点和秋分点。
#
#
# ### 太阳历和太阴历
# 回归年，恒星年，朔望月，纪元，置闰，农历节气
#
# 儒略日和儒略历没有对应关系
#
# 日食，月食
#
# 思考：为什么不是每个朔日都发生月食
